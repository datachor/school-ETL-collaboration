# %%
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import pandas as pd

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/school_db')
conn = engine.connect()
session = Session(engine)

# %%
# Able to connect to the DB and import a table into Pandas
data = pd.read_sql("SELECT * FROM school_distinctive_programs", conn)
data_refined2_df = pd.DataFrame(data)
data_refined2_df
# Out:
#                         school_name                   alp_domain  \
# 0          ADMIRALTY PRIMARY SCHOOL                         STEM
# 1        ADMIRALTY SECONDARY SCHOOL                         STEM
# 2      AHMAD IBRAHIM PRIMARY SCHOOL                      Science
# 3    AHMAD IBRAHIM SECONDARY SCHOOL       Languages & Humanities
# 4                    AI TONG SCHOOL                         NULL
# ..                              ...                          ...
# 283         YUYING SECONDARY SCHOOL  Business & Entrepreneurship
# 284          ZHANGDE PRIMARY SCHOOL                      Science
# 285         ZHENGHUA PRIMARY SCHOOL            Interdisciplinary
# 286       ZHENGHUA SECONDARY SCHOOL                         STEM
# 287         ZHONGHUA PRIMARY SCHOOL                         STEM
#
#                                              alp_title  \
# 0    Design Thinking for Sustainability (DTS @ Admi...
# 1    Design Thinking Through Innovation and Technology
# ...

# %%
data_refined3_df = data_refined2_df.loc[data_refined2_df["alp_domain"] == "STEM",:]
data_refined3_df
# Out:
#                       school_name alp_domain  \
# 0        ADMIRALTY PRIMARY SCHOOL       STEM
# 1      ADMIRALTY SECONDARY SCHOOL       STEM
# 9     ANG MO KIO SECONDARY SCHOOL       STEM
# 15       BARTLEY SECONDARY SCHOOL       STEM
# 17        BEATTY SECONDARY SCHOOL       STEM
# ..                            ...        ...
# 278   YUAN CHING SECONDARY SCHOOL       STEM
# 280        YUHUA SECONDARY SCHOOL       STEM
# 282  YUSOF ISHAK SECONDARY SCHOOL       STEM
# 286     ZHENGHUA SECONDARY SCHOOL       STEM
# 287       ZHONGHUA PRIMARY SCHOOL       STEM
#
#                                              alp_title  \
# 0    Design Thinking for Sustainability (DTS @ Admi...
# 1    Design Thinking Through Innovation and Technology
# 9                     Environment Science & Technology
# 15              Chemical and Life Sciences (Perfumery)
# 17                  Beattyians Think. Create. Innovate
# ..                                                 ...
# ...

# %%
inspector = inspect(engine)

# %%
inspector.get_columns('school_distinctive_programs')
# Out:
# [{'name': 'school_name',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'alp_domain',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'alp_title',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'llp_domain1',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'llp_title1',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'llp_domain2',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'llp_title2',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
# ...

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
SLP = Base.classes.school_distinctive_programs
GIOS = Base.classes.general_information_of_schools

# %%
# Query for All the distinct STEM schools
stem_schools = session.query( SLP.school_name, SLP.alp_domain ).\
    filter( SLP.alp_domain == 'STEM')

# stem_schools.all()
# Creating a list of all the schools
school_list = []
for school in stem_schools:
    school_list.append(school[0])

school_list
# Out:
# ['ADMIRALTY PRIMARY SCHOOL',
#  'ADMIRALTY SECONDARY SCHOOL',
#  'ANG MO KIO SECONDARY SCHOOL',
#  'BARTLEY SECONDARY SCHOOL',
#  'BEATTY SECONDARY SCHOOL',
#  'BEDOK GREEN SECONDARY SCHOOL',
#  'BENDEMEER SECONDARY SCHOOL',
#  'BLANGAH RISE PRIMARY SCHOOL',
#  'BOON LAY SECONDARY SCHOOL',
#  'BROADRICK SECONDARY SCHOOL',
#  'BUKIT BATOK SECONDARY SCHOOL',
#  'BUKIT MERAH SECONDARY SCHOOL',
#  'BUKIT VIEW SECONDARY SCHOOL',
#  'CHANGKAT CHANGI SECONDARY SCHOOL',
#  'CHANGKAT PRIMARY SCHOOL',
#  'CHRIST CHURCH SECONDARY SCHOOL',
#  'CHUA CHU KANG SECONDARY SCHOOL',
#  'CHUNG CHENG HIGH SCHOOL (YISHUN)',
#  'CLEMENTI TOWN SECONDARY SCHOOL',
#  'COMPASSVALE SECONDARY SCHOOL',
#  'DAMAI SECONDARY SCHOOL',
#  'DUNEARN SECONDARY SCHOOL',
#  'EAST SPRING SECONDARY SCHOOL',
#  'FAJAR SECONDARY SCHOOL',
#  'FUCHUN SECONDARY SCHOOL',
#  'FUHUA SECONDARY SCHOOL',
#  'GAN ENG SENG SCHOOL',
#  'GEYLANG METHODIST SCHOOL (SECONDARY)',
#  'GREENDALE SECONDARY SCHOOL',
# ...

# %%
titles = pd.DataFrame(
    {
        "Employee Title": ["Principal", "VP"]
    }
)
titles.to_sql('titles', conn)

# %%
admin_data = session.query( GIOS.school_name, GIOS.principal_name, GIOS.first_vp_name, GIOS.second_vp_name, GIOS.third_vp_name, GIOS.fourth_vp_name, GIOS.fifth_vp_name, GIOS.sixth_vp_name )

# Creating a list to create a data frame
admin_list = []

# Commands to look at the data from the query
# admin_data.all()
# admin_data[0]


for admin in admin_data:
    s = admin[0]
    # print(s)
    for x in range(1, 8):
        person = []
        a = admin[x]
        if x == 1:
            t = 'Principal'
        if x > 1:
            t = 'Vice Principal'
        if admin[x] == 'NULL':
            break        
        person.append(admin[0])
        person.append(a)
        person.append(t)
        admin_list.append(person)

admin_table = pd.DataFrame(admin_list)

# Checking to see that all Six VPs got into the table
# admin_table.loc[admin_table[0] == 'RAFFLES INSTITUTION']

# %%
# Out:
#                        0                               1               2
# 652  RAFFLES INSTITUTION       MR YEO KOK PENG FREDERICK       Principal
# 653  RAFFLES INSTITUTION        MDM THOR POH SIN THERESA  Vice Principal
# 654  RAFFLES INSTITUTION                    MR EDWARD NG  Vice Principal
# 655  RAFFLES INSTITUTION                  MR CHEN ZIYANG  Vice Principal
# 656  RAFFLES INSTITUTION  MR ANG PENG SIONG BRIAN LAGMAN  Vice Principal
# 657  RAFFLES INSTITUTION             MRS REAVLEY MUNN YE  Vice Principal
# 658  RAFFLES INSTITUTION                   MS NG MEI SZE  Vice Principal
